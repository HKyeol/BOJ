# %% [markdown]
# <a href="https://colab.research.google.com/github/HKyeol/BOJ/blob/main/Make_coarse_label_and_custom_dataloader_with_MoveNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # coarse label 로 custom dataloader 만들어보기 (근데 이제 딥러닝 인퍼런스 값을 곁들인..)

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1jzsSh4Ug42LtroOmnZo0MgE7BNMCkaHH?usp=sharing)
#
# ### Author: [@eden_i_m](https://twitter.com/eden_i_m)
#
# ```
# 모두의 연구소에서 진행하는
# "함께 콘텐츠를 제작하는 콘텐츠 크리에이터 모임"
# COCRE(코크리) 1기 회원으로 제작한 글입니다.
# 코크리란? 🐘
# ```

# %% [markdown]
# ## 예상독자
#
# * fine(질좋은, 정확한) label은 아니지만 coarse(조잡한, 대충의) label을 만들어 딥러닝 모델 성능을 높여보고 싶은 사람
# * Keypoint Detection Pre-trained Model로 coarse 라벨을 만들어보고 싶은 사람

# %% [markdown]
# ## 시작하며

# %% [markdown]
# ### 콘텐츠를 만들게된 계기
#
# 저는 model.fit() 벗어나기라는 콘텐츠를 만들고 있었습니다. 내용은 model.fit() 대신 **Train loop**를 만들어 직접 모델을 학습시켜본다는 내용입니다. 총 두 편으로 구성되어있고 관심이 있으시다면 아래를 참고해주세요.
#
#
# *   [model.fit()에서 벗어나기 (1)](https://medium.com/modulabs/model-fit-%EC%97%90%EC%84%9C-%EB%B2%97%EC%96%B4%EB%82%98%EA%B8%B0-b83ee1264e14)
# *   [model.fit()에서 벗어나기 (2)](https://i-am-eden.tistory.com/40)
#
#
# 저는 제 콘텐츠에서 CNN 모델을 이용해 어떤 요가포즈 classification을 학습하는 것을 보여주고 싶었습니다. 하지만 예제코드를 만들면서 저는 제 콘텐츠 문제가 생겼다는 것을 깨달았습니다. 모범이 되어야할 것만 같은 콘텐츠의 딥러닝 모델의 정확도가 너무 낮다는 것이었습니다. 그래서 저는 모델에게 이미지 뿐만 아니라 더 많은 정보를 주기로 결정했습니다. 바로 **딥러닝 모델에 Yogapose(요가를 하는 사람 이미지) 이미지와 해당 이미지에 있는 요가 중인 사람의 keypoints 정보까지 넣어주는 것**이었습니다. 제가 사용하던 데이터를 다운받아보고 싶다면 [이곳](https://www.kaggle.com/datasets/shrutisaxena/yoga-pose-image-classification-dataset)을 참고하세요.
#
# <br/>
#
# 제가 가지고 있었던 데이터는 왼쪽의 **내 요가 데이터**이고 **annotation한 데이터**처럼 keypoints들도 얻고 싶었습니다
#
# <br/>
#
# 내 요가 데이터                  |    annotation한 데이터
# :-------------------------:|:-------------------------:
# ![](https://drive.google.com/uc?id=12caFu0HA8Q92B1ChUyrCzWNiVhCphM4s)  |  ![](https://drive.google.com/uc?id=1o_f01Rbtya2XExiwWJqgbeuBP9K1aWJd)
#
# <p align="center">
#     <em>[그림 1] 요가 데이터</em>
# </p>
#
# </br>
#
# 위 [그림 1]의 annotation한 데이터는 keypoints들과 그 keypoints들을 각각 연결하는 선을 시각화해두었습니다. 이 keypoints의 표현 방법은 아래에서 계속 이야기하겠습니다!

# %% [markdown]
# ### 직접 annotation 해야되는 걸까
#
# 제가 원하는 것을 하기엔 전 이미지 데이터밖에 없었습니다. 즉, 제가 keypoints들을 직접 찍어줘야한다는 것이었죠. 제가 직접 annotation을 해봤을 때 느낀거지만 목과 어깨가 너무도 뻐근하고 피곤합니다. 데이터 회사에 맡기기엔 비싸고, 직접하기엔 너무 피곤하죠..
#
# <br/>
#
# 직접 Annotation을 하지 않는 방법 중에서도 Self-Supervised Learning, Semi-Supervised Learning 모델들이 많이 나오고 있지만 여전히 딥러닝을 하기 위해서 data annotation에 대한 부담은 큽니다.
#
#
# <br/>
# <p align="center">
#     <img src="https://pbs.twimg.com/media/EAmr-PAWsAEoiWR.jpg" width="300"  alt="drawing"/>
# </p>
# <p align="center">
#     <em>[그림 2]하기 싫어..</em>
# </p>
# <br/>
#
# 저는 직접 하나하나 annotation 하기가 너무 싫었습니다! 그리고 저는 완벽하거나 정밀한 label이 아닌 coarse label을 만들어 일단 모델의 정확도가 향상되는지 보고싶었습니다. 대충 coarse label을 만들어보기엔 이미 존재하는 keypoints detection 모델을 사용해 그 inference 값을 사용해보면 좋겠다는 생각이 문득 들었죠!
#
# <br/>
#
#
# 그래서 이미 잘 학습된 keypoints detection model을 찾아보았고, **MoveNet: Ultra fast and accurate pose detection model**를 알게되었습니다. 한국어로 번역한다면 **'짱빠르고 정확한'**이죠. 그 부분이 저를 사로 잡았습니다. 저는 어느정도 만들어진 라벨(여기서는 keypoints)로 대충 제 모델을 돌려보고 싶었거든요.

# %% [markdown]
# ### MoveNet
#
# 기쁘게도 TensoFlow는 아래에 있는 링크에서 제가 원하는 MoveNet을 코랩에서도 돌릴 수 있도록 해놓았습니다. 오예 🔥🔥
#
# https://www.tensorflow.org/hub/tutorials/movenet
#
# <br/>
#
# 하지만 그냥 가져다쓰면 뭔가 얍삽스럽기 때문에 위 링크에 있는 짤막한 **MoveNet**의 설명을 번역하고 약간의 설명을 덧붙이며 이 모델이 어떤건지 알아가는 시간을 짧게 가져보려고 합니다.
#
# <br/>
#
# > **MoveNet** 은 17개로 이루어진 바디 키포인트를 디텍팅하는 짱 빠르고 정확한 모델입니다. 이 모델은 TF Hub 에서 Lightning과 Thunder로 알려진 두 가지 버전(variants)으로 제공됩니다. Lightning은 레이턴시(latency)가 중요한 어플리케이션을 위해 만들어졌고, Thunder는 높은 정확도를 요하는 어플리케이션을 위해 만들어졌습니다. 두 모델은 둘 다 실시간으로 (30+FPS) 데스크톱, 랩톱, 폰에서 사용할 수 있고, 피트니스, 헬스, 웰니스 어플리케이션으로 이는 증명되었습니다. (부가 설명 : latency가 중요하다는 것은 속도가 중요하다는 것입니다.)
#
#
# 이 17개의 keypoints는 COCO 스탠다드를 따랐으며 그 keypoints의 종류는 다음과 같습니다! :
# **"nose", "left_eye", "right_eye", "left_ear", "right_ear", "left_shoulder", "right_shoulder", "left_elbow", "right_elbow", "left_wrist", "right_wrist", "left_hip", "right_hip", "left_knee", "right_knee", "left_ankle", "right_ankle"**
#
# <br/>
# <p align="center">
#     <img src="https://drive.google.com/uc?id=1juZupGISpHP7DgISQn9nL57MP20V0p2n" width="600"  alt="내 드라이브"/>
# </p>
# <p align="center">
#     <em>[그림 3] 17개 keypoints</em>
# </p>
# <br/>
#
# 우리가 아까 위에서 본 [그림 1] 오른쪽의 이미지를 생각해보세요! 총 17개의 keypoints(관절)와 그 관절사이를 잇는 선이 시각화되어 있습니다. [그림 3] 역시 마찬가지입니다. 그렇다면  제가 사용하려는 데이터는 정확히 무엇일까요? 맞습니다. 바로 이미지에 있는 사람의 17개 keypoints의 좌표 (x, y) 값입니다. 총 17개이고 각각 x, y 좌표를 가지고 있기 때문에 (17, 2) 사이즈인 것입니다.
#
#
# <br/><br/>
# 자 이제 어떤 방식으로 제가 사용하고 있는 Yogapose 이미지에 annotation을 해보았는지 보여드릴 차례입니다. TensorFlow가 제공하는 코드와 제 머리에서 나온 코드의 콜라보를 보여드리겠습니다.

# %% [markdown]
# ## 구글 드라이브 마운트하기
#
# 데이터를 매번 코랩에 올렸다 내렸다하기엔 불편합니다. 코랩은 세션이 끝나면 데이터가 싹 사라지기 때문입니다. </br>
# 그래서 데이터를 구글 드라이브에 올려서 그곳에 둔 데이터를 가져와 사용합니다. 하지만 맨 처음 코랩과 내 구글 드라이브는 마운트되어 있지 않습니다. </br> 마운트를 하는 과정이 필요합니다.

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %% [markdown]
# 마운트를 하고 나면 아래 이미지와 같이 `'/content/gdrive/MyDrive'` 아래에 내 구글 드라이브에서 많이 본 디렉토리들이 줄지어 있을 것입니다.
#
# <br/>
# <p align="center">
#     <img src="https://drive.google.com/uc?id=1WrTNf8SX3zvFfyEqbc9B1tML3y5y3W3I" width="300"  alt="내 드라이브"/>
# </p>
# <p align="center">
#     <em>[그림 4] 마운트 성공!</em>
# </p>
# <br/>
#
# 자 이제 데이터를 준비했으니 학습된 짱빠르고 정확한 **MoveNet**을 가져와봅시다.

# %% [markdown]
# ## MoveNet 모델 가져오기 & 환경설정하기

# %% [markdown]
# 저는 movenet_lightning을 사용했습니다. 아까 말씀드렸던 것과 같이 lightning은 주로 빠른 속도를 원할 때 사용합니다. MoveNet으로부터 얻은 keypoints를 통해 학습할 제 CNN 모델의 정확도가 어느 정도 이상 향상 되면 괜찮다고 생각했기 때문에 이 모델을 골랐습니다. 하지만 lightning 보다는 느리지만 keypoints의 정확도가 조금 더 높은 것을 원하시는 분은 Thunder가 좋을 것입니다.

# %%
# !pip install -q imageio
# !pip install -q opencv-python
# !pip install -q git+https://github.com/tensorflow/docs

# %%
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow_docs.vis import embed
import numpy as np
import cv2

# Import matplotlib libraries
from matplotlib import pyplot as plt
from matplotlib.collections import LineCollection
import matplotlib.patches as patches

# Some modules to display an animation using imageio.
import imageio
from IPython.display import HTML, display

# %%
model_name = "movenet_lightning"

if "tflite" in model_name:
    if "movenet_lightning_f16" in model_name:
        # !wget -q -O model.tflite https://tfhub.dev/google/lite-model/movenet/singlepose/lightning/tflite/float16/4?lite-format=tflite
        input_size = 192
    elif "movenet_thunder_f16" in model_name:
        # !wget -q -O model.tflite https://tfhub.dev/google/lite-model/movenet/singlepose/thunder/tflite/float16/4?lite-format=tflite
        input_size = 256
    elif "movenet_lightning_int8" in model_name:
        # !wget -q -O model.tflite https://tfhub.dev/google/lite-model/movenet/singlepose/lightning/tflite/int8/4?lite-format=tflite
        input_size = 192
    elif "movenet_thunder_int8" in model_name:
        # !wget -q -O model.tflite https://tfhub.dev/google/lite-model/movenet/singlepose/thunder/tflite/int8/4?lite-format=tflite
        input_size = 256
    else:
        raise ValueError("Unsupported model name: %s" % model_name)

    # Initialize the TFLite interpreter
    interpreter = tf.lite.Interpreter(model_path="model.tflite")
    interpreter.allocate_tensors()

    def movenet(input_image):
      """Runs detection on an input image.

      Args:
        input_image: A [1, height, width, 3] tensor represents the input image
          pixels. Note that the height/width should already be resized and match the
          expected input resolution of the model before passing into this function.

      Returns:
        A [1, 1, 17, 3] float numpy array representing the predicted keypoint
        coordinates and scores.
      """
      # TF Lite format expects tensor type of uint8.
      input_image = tf.cast(input_image, dtype=tf.uint8)
      input_details = interpreter.get_input_details()
      output_details = interpreter.get_output_details()
      interpreter.set_tensor(input_details[0]['index'], input_image.numpy())
      # Invoke inference.
      interpreter.invoke()
      # Get the model prediction.
      keypoints_with_scores = interpreter.get_tensor(output_details[0]['index'])
      return keypoints_with_scores

else:
  if "movenet_lightning" in model_name:
      module = hub.load("https://tfhub.dev/google/movenet/singlepose/lightning/4")
      input_size = 192
  elif "movenet_thunder" in model_name:
      module = hub.load("https://tfhub.dev/google/movenet/singlepose/thunder/4")
      input_size = 256
  else:
      raise ValueError("Unsupported model name: %s" % model_name)

  def movenet(input_image):
    """Runs detection on an input image.

    Args:
      input_image: A [1, height, width, 3] tensor represents the input image
        pixels. Note that the height/width should already be resized and match the
        expected input resolution of the model before passing into this function.

    Returns:
      A [1, 1, 17, 3] float numpy array representing the predicted keypoint
      coordinates and scores.
    """
    model = module.signatures['serving_default']

    # SavedModel format expects tensor type of int32.
    input_image = tf.cast(input_image, dtype=tf.int32)
    # Run model inference.
    outputs = model(input_image)
    # Output is a [1, 1, 17, 3] tensor.
    keypoints_with_scores = outputs['output_0'].numpy()
    return keypoints_with_scores

# %% [markdown]
# ## Annotation할 데이터 가져오기

# %% [markdown]
# Annotation할 즉, body keypoint가 필요한 이미지 데이터들을 가져옵니다.

# %%
import os
from pathlib import Path

# 마운트시킨 데이터 셋 위치
data_path = '/content/gdrive/MyDrive/dataset'
classes = [path for path in Path(data_path).iterdir() if path.is_dir()]
classes
# Out:
# [PosixPath('/content/gdrive/MyDrive/dataset/ardha matsyendrasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/agnistambhasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/ardha bhekasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/ardha pincha mayurasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/anjaneyasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/ardha chandrasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/ananda balasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/adho mukha svanasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/anantasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/adho mukha vriksasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/bharadvajasana i'),
#  PosixPath('/content/gdrive/MyDrive/dataset/bhairavasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/balasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/astavakrasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/baddha konasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/bhekasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/ashtanga namaskara'),
#  PosixPath('/content/gdrive/MyDrive/dataset/bhujangasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/ardha uttanasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/bakasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/bhujapidasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/dhanurasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/dwi pada viparita dandasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/eka pada koundinyanasana i'),
#  PosixPath('/content/gdrive/MyDrive/dataset/durvasasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/chaturanga dandasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/bitilasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/camatkarasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/dandasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/chakravakasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/eka pada koundinyanasana ii'),
#  PosixPath('/content/gdrive/MyDrive/dataset/eka pada rajakapotasana ii'),
#  PosixPath('/content/gdrive/MyDrive/dataset/gomukhasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/ganda bherundasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/halasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/hanumanasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/garudasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/janu sirsasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/garbha pindasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/eka pada rajakapotasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/marjaryasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/malasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/marichyasana i'),
#  PosixPath('/content/gdrive/MyDrive/dataset/makarasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/makara adho mukha svanasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/marichyasana iii'),
#  PosixPath('/content/gdrive/MyDrive/dataset/lolasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/kurmasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/kapotasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/krounchasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/padangusthasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/parivrtta trikonasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/matsyasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/mayurasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/padmasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/parivrtta janu sirsasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/parighasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/natarajasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/paripurna navasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/parivrtta parsvakonasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/prasarita padottanasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/parsvottanasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/parsva bakasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/salabhasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/pincha mayurasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/pasasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/purvottanasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/phalakasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/salamba bhujangasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/paschimottanasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/salamba sarvangasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/simhasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/sukhasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/supta padangusthasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/supta virasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/setu bandha sarvangasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/salamba sirsasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/supta matsyendrasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/supta baddha konasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/savasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/urdhva mukha svanasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/tulasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/tittibhasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/urdhva prasarita eka padasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/tadasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/ustrasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/urdhva dhanurasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/upavistha konasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/tolasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/urdhva hastasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/uttana shishosana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/utthita ashwa sanchalanasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/utthita hasta padangustasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/utkatasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/utthita trikonasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/utthita parsvakonasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/vasisthasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/uttanasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/viparita karani'),
#  PosixPath('/content/gdrive/MyDrive/dataset/vajrasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/vrischikasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/virabhadrasana iii'),
#  PosixPath('/content/gdrive/MyDrive/dataset/virasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/yoganidrasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/virabhadrasana ii'),
#  PosixPath('/content/gdrive/MyDrive/dataset/vriksasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/virabhadrasana i')]

# %% [markdown]
# </br>
#
# 위의 코드에서 내가 가진 데이터 셋은 예시로 보여주기엔 클래스가 너무 많습니다. 그래서 저는 2개의 클래스만 사용하도록 하겠습니다.
#
# 아래의 코드는 우리가 가진 클래스(디렉토리 이름과 동일)의 모든 파일들의 경로를 가져옵니다.

# %%
classes = classes[:2]
classes
# Out:
# [PosixPath('/content/gdrive/MyDrive/dataset/ardha matsyendrasana'),
#  PosixPath('/content/gdrive/MyDrive/dataset/agnistambhasana')]

# %% [markdown]
# 자 이제 우리에게는 'ardha matsyendrasana', 'agnistambhasana' 두개의 클래스만 남았습니다.
# 두 클래스의 파일 경로를 모두 불러올 것입니다.

# %%
files = []
for cls in classes:
  files += [x.as_posix() for x in Path(cls).glob('**/*') if x.is_file()]
files
# Out:
# ['/content/gdrive/MyDrive/dataset/ardha matsyendrasana/69-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/75-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/34-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/18-2.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/62-2.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/73-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/81-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/91-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/63-2.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/56-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/46-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/57-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/87-2.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/66-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/68-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/19-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/1-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/12-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/40-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/67-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/44-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/26-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/18-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/83-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/76-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/62-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/45-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/78-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/52-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/74-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/50-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/87-3.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/25-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/72-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/71-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/47-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/86-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/2-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/53-2.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/15-5.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/57-1.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/70-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/20-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/49-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/95-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/17-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/90-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/46-1.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/64-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/23-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/9-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/79-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/51-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/0-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/14-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/77-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/87-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/58-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/63-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/90-1.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/24-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/28-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/31-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/93-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/18-1.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/42-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/59-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/8-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/16-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/53-1.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/63-1.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/37-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/36-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/41-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/55-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/10-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/43-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/39-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/84-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/53-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/60-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/87-1.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/54-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/22-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/98-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/48-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/61-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/80-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/4-0.png',
#  '/content/gdrive/MyDrive/dataset/ardha matsyendrasana/6-0.png',
#  '/content/gdrive/MyDrive/dataset/agnistambhasana/32-0.png',
#  '/content/gdrive/MyDrive/dataset/agnistambhasana/23-0.png',
#  '/content/gdrive/MyDrive/dataset/agnistambhasana/12-0.png',
#  '/content/gdrive/MyDrive/dataset/agnistambhasana/2-0.png',
#  '/content/gdrive/MyDrive/dataset/agnistambhasana/11-0.png',
#  '/content/gdrive/MyDrive/dataset/agnistambhasana/36-0.png',
#  '/content/gdrive/MyDrive/dataset/agnistambhasana/34-0.png',
#  '/content/gdrive/MyDrive/dataset/agnistambhasana/14-0.png',
#  '/content/gdrive/MyDrive/dataset/agnistambhasana/20-0.png',
#  '/content/gdrive/MyDrive/dataset/agnistambhasana/26-0.png',
#  '/content/gdrive/MyDrive/dataset/agnistambhasana/10-0.png',
#  '/content/gdrive/MyDrive/dataset/agnistambhasana/33-0.png',
#  '/content/gdrive/MyDrive/dataset/agnistambhasana/15-0.png',
#  '/content/gdrive/MyDrive/dataset/agnistambhasana/21-0.png',
#  '/content/gdrive/MyDrive/dataset/agnistambhasana/13-1.png',
#  '/content/gdrive/MyDrive/dataset/agnistambhasana/1-0.png',
#  '/content/gdrive/MyDrive/dataset/agnistambhasana/22-0.png',
#  '/content/gdrive/MyDrive/dataset/agnistambhasana/30-0.png',
#  '/content/gdrive/MyDrive/dataset/agnistambhasana/86-0.png',
#  '/content/gdrive/MyDrive/dataset/agnistambhasana/46-0.png',
#  '/content/gdrive/MyDrive/dataset/agnistambhasana/57-0.png',
#  '/content/gdrive/MyDrive/dataset/agnistambhasana/4-0.png',
#  '/content/gdrive/MyDrive/dataset/agnistambhasana/43-0.png',
#  '/content/gdrive/MyDrive/dataset/agnistambhasana/66-0.png',
#  '/content/gdrive/MyDrive/dataset/agnistambhasana/42-0.png',
#  '/content/gdrive/MyDrive/dataset/agnistambhasana/47-0.png',
#  '/content/gdrive/MyDrive/dataset/agnistambhasana/48-0.png',
#  '/content/gdrive/MyDrive/dataset/agnistambhasana/9-0.png',
#  '/content/gdrive/MyDrive/dataset/agnistambhasana/45-0.png',
#  '/content/gdrive/MyDrive/dataset/agnistambhasana/61-0.png',
#  '/content/gdrive/MyDrive/dataset/agnistambhasana/90-0.png',
#  '/content/gdrive/MyDrive/dataset/agnistambhasana/87-0.png',
#  '/content/gdrive/MyDrive/dataset/agnistambhasana/38-0.png']

# %% [markdown]
# ## Inference 해서 json으로 저장하기
#
# 아래는 TensorFlow 에서 제공하는 코드를 기반으로 17개의 body key points만을 리턴하도록 수정한 코드입니다.

# %%
def get_keypoints(image, 
                  keypoints_with_scores,
                  output_image_height=None, 
                  keypoint_threshold=0.0):
    height, width, channel = image.shape
    aspect_ratio = float(width) / height

    keypoints_all = []
    num_instances,_,_,_ = keypoints_with_scores.shape
    for id in range(num_instances):
        kpts_x = keypoints_with_scores[0,id,:,1]
        kpts_y = keypoints_with_scores[0,id,:,0]
        kpts_scores = keypoints_with_scores[0,id,:,2]
        kpts_abs_xy = np.stack(
            [width*np.array(kpts_x),height*np.array(kpts_y)],axis=-1)
        kpts_above_thrs_abs = kpts_abs_xy[kpts_scores > keypoint_threshold,: ]
        keypoints_all.append(kpts_above_thrs_abs)

    return np.concatenate(keypoints_all,axis=0)

# %% [markdown]
# 자, 이제! file들을 각각 inference해서 `{'file path' : (17, 2) 배열}` 상태로 dictionary에 저장해봅시다!

# %%
import json

keypoints = {}

for image_path in files:
    # 이미지 에러에 대한 처리
    # 이미지가 tf.io.read_file로 읽을 수 없는 타입인 경우에 대비
    try:
        image = tf.io.read_file(image_path)
        image = tf.image.decode_jpeg(image)
    except:
        print('image error : ', image_path)
        continue

    input_image = tf.expand_dims(image, axis=0)
    input_image = tf.image.resize_with_pad(input_image, input_size, input_size)

    # 모델 인퍼런스 에러에 대한 처리
    try:
        keypoints_with_scores = movenet(input_image)
    except:
        print('model error : ', image_path)
        continue

    display_image = tf.expand_dims(image, axis=0)
    display_image = tf.cast(tf.image.resize_with_pad(
        display_image, 224, 224), dtype=tf.int32)
    output_overlay = get_keypoints(np.squeeze(display_image.numpy(), axis=0), 
                                  keypoints_with_scores)
    
    keypoints.setdefault('/'.join(image_path.split('/')[3:]), output_overlay.tolist())

# %%
keypoints
# Out:
# {'MyDrive/dataset/agnistambhasana/1-0.png': [[112.5881576538086,
#    62.95499801635742],
#   [121.22173309326172, 51.51435470581055],
#   [103.03868865966797, 51.12981414794922],
#   [133.76551818847656, 47.531280517578125],
#   [90.13893127441406, 46.04570770263672],
#   [147.6146240234375, 84.63640594482422],
#   [70.38396453857422, 85.6873779296875],
#   [185.17190551757812, 121.20535278320312],
#   [46.1644287109375, 124.40988159179688],
#   [183.20822143554688, 169.6873779296875],
#   [43.57609558105469, 171.6707305908203],
#   [135.8099365234375, 162.4068603515625],
#   [89.73326110839844, 161.1866455078125],
#   [173.9693603515625, 191.6814422607422],
#   [33.51499938964844, 148.6276397705078],
#   [148.770263671875, 69.78659057617188],
#   [27.821901321411133, 199.8330078125],
#   [114.62567901611328, 173.27706909179688],
#   [68.65666198730469, 185.32427978515625],
#   [168.04867553710938, 173.55043029785156],
#   [146.4585723876953, 130.34036254882812],
#   [136.669677734375, 192.52420043945312],
#   [163.00425720214844, 187.3169403076172]],
#  'MyDrive/dataset/ardha matsyendrasana/95-0.png': [[91.86558532714844,
#    33.46630096435547],
#   [102.0955810546875, 25.933422088623047],
#   [92.88346099853516, 24.95984649658203],
#   [124.91657257080078, 32.30829620361328],
#   [100.3173828125, 27.30481719970703],
#   [142.0573272705078, 78.9968032836914],
#   [67.66527557373047, 73.31858825683594],
#   [164.5938262939453, 146.4747314453125],
#   [44.986873626708984, 138.37216186523438],
#   [110.08070373535156, 156.8214569091797],
#   [73.97561645507812, 157.42665100097656],
#   [127.37528991699219, 187.60177612304688],
#   [69.05953979492188, 183.86233520507812],
#   [173.93212890625, 208.12831115722656],
#   [118.61996459960938, 156.7159881591797],
#   [65.09158325195312, 216.87448120117188],
#   [62.22405242919922, 218.48980712890625]],
#  'MyDrive/dataset/ardha matsyendrasana/98-0.png': [[91.88294219970703,
#    52.98286437988281],
#   [99.44386291503906, 46.143524169921875],
#   [94.61579895019531, 45.55219268798828],
#   [119.57320404052734, 50.990909576416016],
#   [109.86742401123047, 48.35060501098633],
#   [145.63809204101562, 85.04285430908203],
#   [84.465087890625, 85.1255111694336],
#   [171.84703063964844, 132.0309600830078],
#   [59.886940002441406, 131.6212158203125],
#   [196.97772216796875, 171.896484375],
#   [32.24197006225586, 170.62957763671875],
#   [129.2795867919922, 172.01889038085938],
#   [101.2863998413086, 171.93161010742188],
#   [67.28182983398438, 121.83438873291016],
#   [38.15977478027344, 174.7068328857422],
#   [37.794822692871094, 177.8982696533203],
#   [110.37763214111328, 190.4540252685547]]}

# %% [markdown]
# 위에서 keypoints dictionary를 확인해보니 잘 저장이 된 것 같네요!
# 이제 json 파일로 저장해봅시다. 아래의 명령어를 실행해보면 `/content/keypoints.json` 이라는 json 파일이 생길것입니다.
#
#
# <br/>
# <p align="center">
#     <img src="https://drive.google.com/uc?id=1BOiSKrQ8_FImHgao-QrlrHD2Zb2Tl91Y" width="300"  alt="내 드라이브"/>
# </p>
# <p align="center">
#     <em>[그림 5] json 파일 저장하기</em>
# </p>
# <br/>

# %%
with open("./keypoints.json", "w") as json_file:
    json.dump(keypoints, json_file)

# %% [markdown]
# 이 json 파일을 마우스 우클릭으로 저장할 수도 있지만 아래의 명령어를 사용하면 코드를 사용하여 내 로컬 PC에 파일을 저장할 수 있습니다!

# %%
from google.colab import files
files.download("./keypoints.json")

# %% [markdown]
# ## 이미지 데이터와 keypoints 데이터를 로드하는 데이터로더 만들기

# %% [markdown]
# 데이터를 만들었으니 이제 기존에 가지고 있던 이미지만 로드하는 데이터로더가 아닌 이미지와 keypoints 모두를 로드하는 데이터로더가 필요합니다. </br>
# 우리의 새 데이터로더는 `image, label` 형태가 아닌 `{"input_1": img, "input_2": keypoint}, label`로 데이터를 로드할 것입니다!

# %%
import os
import pathlib

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

import json

with open("./keypoints.json", "r") as json_file:
    keypoint_dict = json.load(json_file)

new_keypoint_dict = {}
for key in keypoint_dict.keys():
    new_key = '/'.join(key.split('/')[-2:])
    new_val = keypoint_dict[key]
    new_keypoint_dict[new_key] = new_val

del keypoint_dict
keypoint_dict = new_keypoint_dict
del new_keypoint_dict

def process_keypoint(file_path):
    file_path =  '/'.join(file_path.numpy().decode('utf-8').split('/')[-2:])
    # keypoint = np.array(keypoint_dict[file_path])
    keypoint = tf.convert_to_tensor(keypoint_dict[file_path], dtype=tf.float32)
    return keypoint

def process_path(file_path, class_names, img_shape=(224, 224)):
    label = tf.strings.split(file_path, os.path.sep)
    label = label[-2] == class_names
    label = tf.cast(label, tf.float32)

    img = tf.io.read_file(file_path)
    img = tf.image.decode_png(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = tf.image.resize(img, img_shape) 
    # img = img / 255.0

    [keypoint,] = tf.py_function(process_keypoint, [file_path], [tf.float32])

    return {"input_1": img, "input_2": keypoint}, label


def load_label(label_path):
    class_names = []
    with open(label_path) as f:
        for line in f:
            line = line.strip()
            class_names.append(line)

    return np.array(class_names)


def get_spilt_data(ds, ds_size, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=1000):
    assert (train_split + val_split) == 1

    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)

    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)

    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)

    return train_ds, val_ds


def augment(inputs, label):
    image, keypoint = inputs['input_1'], inputs['input_2']
    image = tf.image.random_crop(image, size=[224, 224, 3])
    image = tf.image.adjust_brightness(image, 0.4)
    image = tf.image.random_brightness(image, max_delta=0.4)
    return {'input_1' : image, 'input_2' : keypoint}, label


def prepare_for_training(ds, batch_size=32, cache=True, training=True):
    if cache:
        if isinstance(cache, str):
            ds = ds.cache(cache)
        else:
            ds = ds.cache()

    ds = ds.repeat()
    if training:
        ds = ds.map(lambda x, y: augment(x, y))
    ds = ds.batch(batch_size)
    ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

    return ds


def load_data(data_path, img_shape, batch_size=32, is_train=True):
    class_names = [cls for cls in os.listdir(data_path) if cls != '.DS_Store']
    data_dir = pathlib.Path(data_path)
    list_ds = tf.data.Dataset.list_files(str(data_dir / '*/*'))

    labeled_ds = list_ds.map(lambda x: process_path(x, class_names, img_shape))
    labeled_ds = prepare_for_training(labeled_ds, batch_size=batch_size, training=is_train)

    DATASET_SIZE = tf.data.experimental.cardinality(list_ds).numpy()

    return labeled_ds, DATASET_SIZE

# %% [markdown]
# 코드에 대한 약간의 설명이 필요할 것 같습니다.
#
# ```python
# def load_data(data_path, img_shape, batch_size=32, is_train=True):
#     class_names = [cls for cls in os.listdir(data_path) if cls != '.DS_Store']
#     data_dir = pathlib.Path(data_path)
#     list_ds = tf.data.Dataset.list_files(str(data_dir / '*/*'))
#
#     labeled_ds = list_ds.map(lambda x: process_path(x, class_names, img_shape))
#     labeled_ds = prepare_for_training(labeled_ds, batch_size=batch_size, training=is_train)
#
#     DATASET_SIZE = tf.data.experimental.cardinality(list_ds).numpy()
#
#     return labeled_ds, DATASET_SIZE
# ```
#
# `load_data`의 역할은 라벨 로드, 이미지 로드, 데이터 배치 만들기 등의 역할을 하는 함수를 호출하여 최종으로 받을 데이터를 만드는 역할을 합니다. `load_data`에서 호출하는 함수들을 차례로 확인해봅시다.

# %% [markdown]
# 이전처럼 single input을 사용하는 모델이라면 `prcoess_path`에서 **img, label을 return**을 해주었을 것입니다.
# 하지만 지금은 들어오는 img뿐만 아니라 keypoints도 가져와야 합니다.
# `process_keypoint` 함수를 이용하여 keypoint를 가져온 후 **img, keypoint, label을 리턴**해줍니다.
#
# ```python
# def process_keypoint(file_path):
#     file_path =  '/'.join(file_path.numpy().decode('utf-8').split('/')[-2:])
#     # keypoint = np.array(keypoint_dict[file_path])
#     keypoint = tf.convert_to_tensor(keypoint_dict[file_path], dtype=tf.float32)
#     return keypoint
#
# def process_path(file_path, class_names, img_shape=(224, 224)):
#     label = tf.strings.split(file_path, os.path.sep)
#     label = label[-2] == class_names
#     label = tf.cast(label, tf.float32)
#
#     img = tf.io.read_file(file_path)
#     img = tf.image.decode_png(img, channels=3)
#     img = tf.image.convert_image_dtype(img, tf.float32)
#     img = tf.image.resize(img, img_shape)
#     # img = img / 255.0
#
#     [keypoint,] = tf.py_function(process_keypoint, [file_path], [tf.float32])
#
#     return {"input_1": img, "input_2": keypoint}, label
# ```

# %% [markdown]
# prepare_for_training에서 augmentation 해줄 때도 `image, keypoint = inputs['input_1'], inputs['input_2']`를 통해 image를 가져와서 image만 augmentation 해주어야 합니다. 이 때 주의할 점은, 우리는 keypoints를 사용할 것이기 때문에 좌우 flip과 같은 augmentation은 하지 않도록 해야합니다.
#
# ```python
# def augment(inputs, label):
#     image, keypoint = inputs['input_1'], inputs['input_2']
#     image = tf.image.random_crop(image, size=[224, 224, 3])
#     image = tf.image.adjust_brightness(image, 0.4)
#     image = tf.image.random_brightness(image, max_delta=0.4)
#     return {'input_1' : image, 'input_2' : keypoint}, label
#
#
# def prepare_for_training(ds, batch_size=32, cache=True, training=True):
#     if cache:
#         if isinstance(cache, str):
#             ds = ds.cache(cache)
#         else:
#             ds = ds.cache()
#
#     ds = ds.repeat()
#     if training:
#         ds = ds.map(lambda x, y: augment(x, y))
#     ds = ds.batch(batch_size)
#     ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
#
#     return ds
# ```

# %% [markdown]
# 자 이제 데이터를 잘 가져오는지 확인해볼까요?
# 아까 우리는 2개의 클래스 `'ardha matsyendrasana', 'agnistambhasana'` 대해서만 json 파일을 만들었으니 그 점 유의하세요!

# %%
# 내 데이터 위치
train_data_path = '/content/dataset'

train_ds, train_size = load_data(data_path=train_data_path, img_shape=(224, 224), batch_size=1)

for inputs, label in train_ds.take(1):
    print(inputs)
    print(label)
# Out:
# {'input_1': <tf.Tensor: shape=(1, 224, 224, 3), dtype=float32, numpy=
# array([[[[0.9739525 , 0.97787404, 0.95486677],
#          [0.9669877 , 0.9709093 , 0.9496733 ],
#          [0.96182317, 0.96574473, 0.94450873],
#          ...,
#          [1.0314485 , 1.0392916 , 1.0196838 ],
#          [1.0273342 , 1.0389066 , 1.0205418 ],
#          [1.020206  , 1.0398138 , 1.0241275 ]],
#
#         [[0.9982743 , 0.99578595, 0.97073734],
#          [0.9901419 , 0.98924905, 0.96860826],
#          [0.98583597, 0.98507637, 0.9641691 ],
#          ...,
#          [1.0250477 , 1.0367423 , 1.0180974 ],
#          [1.0224574 , 1.0369656 , 1.019869  ],
#          [1.017758  , 1.0383288 , 1.0245683 ]],
#
#         [[1.0072713 , 1.0036999 , 0.97073424],
#          [1.0138822 , 0.9983992 , 0.9862279 ],
#          [1.0124359 , 1.0006711 , 0.98106337],
#          ...,
#          [1.0154647 , 1.0389941 , 1.0233078 ],
#          [1.0117463 , 1.0352757 , 1.0220757 ],
#          [1.0087441 , 1.0322735 , 1.0244304 ]],
#
#         ...,
#
#         [[1.1485006 , 1.034775  , 0.9702442 ],
#          [1.145822  , 1.0320965 , 0.9615083 ],
#          [1.1445378 , 1.0308123 , 0.96022403],
#          ...,
#          [1.2027551 , 1.0739384 , 0.99913096],
#          [1.192275  , 1.0634582 , 0.9886509 ],
#          [1.1812935 , 1.0524766 , 0.97766936]],
#
#         [[1.1583309 , 1.0446055 , 0.97401726],
#          [1.1550381 , 1.0413126 , 0.97072434],
#          [1.1563854 , 1.0426599 , 0.97207165],
#          ...,
#          [1.1942916 , 1.0589623 , 0.98445255],
#          [1.1938283 , 1.0584991 , 0.98398924],
#          [1.194448  , 1.0591187 , 0.9846089 ]],
#
#         [[1.1729198 , 1.062223  , 0.9825486 ],
#          [1.1716623 , 1.0579368 , 0.98734856],
#          [1.1690514 , 1.055326  , 0.9847377 ],
#          ...,
#          [1.1609123 , 1.0236573 , 0.9491475 ],
#          [1.170541  , 1.0332861 , 0.95877635],
#          [1.1762483 , 1.0389934 , 0.9644836 ]]]], dtype=float32)>, 'input_2': <tf.Tensor: shape=(1, 17, 2), dtype=float32, numpy=
# array([[[173.72876 ,  30.358376],
#         [169.47363 ,  24.053658],
#         [165.32196 ,  24.752483],
#         [154.65726 ,  29.998938],
#         [144.64984 ,  32.596394],
#         [192.50554 ,  68.571106],
#         [118.11632 ,  67.97858 ],
#         [193.38287 , 120.07662 ],
#         [ 80.692444, 120.286575],
#         [160.82112 , 160.14615 ],
#         [101.04594 , 165.27475 ],
#         [159.3426  , 176.42587 ],
#         [126.87529 , 169.75961 ],
#         [ 85.28093 , 111.91662 ],
#         [ 39.076916, 185.32555 ],
#         [ 84.161354, 191.12975 ],
#         [122.59808 , 204.92035 ]]], dtype=float32)>}
# tf.Tensor([[0. 0. 1.]], shape=(1, 3), dtype=float32)

# %% [markdown]
# 오! 아주 로드가 잘되고 있습니다. 자 이제 입력이 두 개인 multiple input을 가진 모델로 바꿔보겠습니다!

# %% [markdown]
# ## Multi-input 모델 만들기

# %%
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications import VGG16

class YogaPose(tf.keras.Model):
    def __init__(self, num_classes=30, freeze=False):
        super(YogaPose, self).__init__()
        self.base_model = EfficientNetB0(include_top=False, weights='imagenet')
        self.keypoint = tf.keras.Sequential([tf.keras.layers.Flatten(input_shape=(17, 2)),
                                              tf.keras.layers.Dense(34),])
        
        if freeze:
            self.base_model.trainable = False

        self.top = tf.keras.Sequential([tf.keras.layers.GlobalAveragePooling2D(name="avg_pool"),
                                        tf.keras.layers.BatchNormalization(),
                                        tf.keras.layers.Dropout(0.6, name="top_dropout")])
        
        self.concat = tf.keras.layers.Concatenate(axis=-1)
        self.classifier = tf.keras.layers.Dense(num_classes, activation="softmax", name="pred")

    def call(self, inputs, training=True):
        image, keypoint = inputs['input_1'], inputs['input_2']
        x1 = self.base_model(image)
        x1 = self.top(x1)
        x2 = self.keypoint(keypoint)
        x = self.concat([x1, x2])
        x = self.classifier(x)
        return x

# %% [markdown]
# call function을 통해 input이 들어오게 되겠죠?
# 우리의 dataloader가 리턴해주는 데이터의 형태는 `{"input_1": img, "input_2": keypoint}, label`이기 때문에
# `image, keypoint = inputs['input_1'], inputs['input_2']` 코드처럼 image, keypoint 각각을 저장해야 합니다.
#
# ```python
# def call(self, inputs, training=True):
#     image, keypoint = inputs['input_1'], inputs['input_2']
#     x1 = self.base_model(image)
#     x1 = self.top(x1)
#     x2 = self.keypoint(keypoint)
#     x = self.concat([x1, x2])
#     x = self.classifier(x)
#     return x
# ```
#
# 그리고 위의 코드처럼 각각의 입력을 받아줄 레이어도 지정해줍니다.
# **image**를 받을 레이어는 **self.base_model**, **keypoint**를 받을 레이어는 **self.keypoint** 입니다.
#
# 자 이제 모델이 어떤 input을 넣었을 때 output이 잘 나오는지 볼까요?

# %%
# 가짜 input
inputs = {'input_1':tf.ones([1, 224, 224, 3]), 'input_2':tf.ones([1, 17, 2])}
model = YogaPose(num_classes=2, freeze=True)
model(inputs)
# Out:
# <tf.Tensor: shape=(1, 2), dtype=float32, numpy=array([[0.49523163, 0.5047684 ]], dtype=float32)>

# %% [markdown]
# 값이 잘 나오네요!
#
# <br/>
# <p align="center">
#     <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSd_UxYRogh8GYIAdjznBsAxhMHQH2KSa0iUA&usqp=CAU" width="300"  alt="drawing"/>
# </p>
# <p align="center">
#     <em>[그림 6] 오예 🎉</em>
# </p>
# <br/>
#
#
# 이제 모델을 학습해서 결과를 보는 일만 남았네요. 그 일은 model.fit()에서 벗어나기! (2)에서 계속 진행해보겠습니다. 해당 콘텐츠는 피어리뷰 이후에 약간의 수정을 거쳐 코크리 블로그에 올라올 예정입니다! 기대해주세요.

# %% [markdown]
# 1.   참고자료
#   * TensorFlow MoveNet : https://www.tensorflow.org/hub/tutorials/movenet
#
# 2.   그림 출처
#   * [그림 1] : https://han.gl/YSqIN
#   * [그림 2] : https://han.gl/amUCC
#   * [그림 3] : https://viso.ai/computer-vision/coco-dataset/
#   * [그림 4] : Author
#   * [그림 5] : Author
#   * [그림 6] : http://www.quickmeme.com/meme/3s0pe3
